# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
for columns in df.columns:
    print(f"Column Name: {columns} : {df[columns].dtype}", end='\n')
# Out:
# Column Name: ID : int64
# Column Name: Age : int64
# Column Name: Salary : int64
# Column Name: Gender : object
# Column Name: Department : object
# Column Name: Experience : int64
# Column Name: Satisfaction_Score : int64

# %%
df['Department'].unique()
# Out:
# array(['HR', 'Finance', 'Sales'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# <Axes: >
